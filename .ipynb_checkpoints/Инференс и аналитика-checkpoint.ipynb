# %% [markdown]
# # Библиотеки

# %%
from classes_and_definitions import *
import pickle
import time 
from tqdm import tqdm
from datetime import datetime
import warnings

warnings.filterwarnings("ignore")

# %% [markdown]
# # Загрузка данных и пример использования

# %% [markdown]
# ## Инициализируем объект класса для прогнозирования

# %%
with open('./Вспомогательные файлы/category_models.pkl', 'rb') as f:
    topic_modeling_dict = pickle.load(f)
    
with open('./Вспомогательные файлы/sentiment_classifier.pkl', 'rb') as f:
    sentiment_classifier = pickle.load(f)
    
with open('./Вспомогательные файлы/product_classifer.pkl', 'rb') as f:
    product_classifier = pickle.load(f)

with open('./Вспомогательные файлы/allowed_lemmas.pkl', 'rb') as f:
    allowed_lemmas = pickle.load(f)
    tokenizer=NLTKWordTokenizer()
    text_transformer = TextTransformer(allowed_lemmas)
    
mapping = dict()

mapping['autocredits'] = {0: {0: 'Неудовлетворительные условия кредитования',
                             1: 'Проблемы с процессом обращения и обработки заявки',
                             2: 'Проблемы с платежами и погашением кредита',
                             3: 'Проблемы с залогом и автомобилем',
                             4: 'Неудовлетворенность условиями автокредита'},
                         1: {0: 'Хорошее обслуживание',
                             1: 'Удовлетворенность процессом оформления автокредита',
                             2: 'Удовлетворенность условиями кредита и выплатами по кредиту',
                             3: 'Удовлетворенность процессом закрытия автокредита',
                             4: 'Положительный опыт использования рассрочки'}
                         }

mapping['credits'] = {0: {0: 'Проблемы с условиями кредита и страхованием',
                             1: 'Проблемы с обслуживанием и обработкой заявок',
                             2: 'Проблемы с платежами и счетами',
                             3: 'Проблемы с кредитной историей и исполнительным производством',
                             4: 'Проблемы с обращением в банк и услугами поддержки'},
                         1: {0: 'Положительный опыт общения с сотрудниками банка',
                             1: 'Быстрое оформление кредита',
                             2: 'Положительный опыт использования мобильного приложения',
                             3: 'Поддержка для развития бизнеса',
                             4: 'Удобство и гибкость условий использования кредитной карты'}
                         }

mapping['deposits'] = {0: {0: 'Проблемы с исполнительным производством и взысканием долгов',
                             1: 'Проблемы с доступом к счету',
                             2: 'Проблемы с обработкой заявок по горячей линии',
                             3: 'Проблемы с комиссиями и снятием средств с депозитов',
                             4: 'Неудовлетворительные условия депозитов'},
                         1: {0: 'Удовлетворенность гибкими условиями депозитов',
                             1: 'Положительный опыт обслуживания в отделении',
                             2: 'Удовлетворение услугами депозитов, предоставляемыми с использованием карточки',
                             3: 'Удовлетворение качеством мобильного приложения банка',
                             4: 'Удовлетворение процентными ставками и удобством общения с операторами'}
                         }

mapping['hypothec'] = {0: {0: 'Проблемы с условиями ипотечного кредитования',
                             1: 'Отказы по ипотеке и проблемы с коммуникацией с менеджерами',
                             2: 'Проблемы с платежами и денежными операциями по ипотеке',
                             3: 'Сложность процедуры получения ипотеки',
                             4: 'Проблемы со страховкой при оформлении ипотеки'},
                         1: {0: 'Удовлетворенность процессом осуществлени сделки',
                             1: 'Положительный опыт обслуживания в отделении',
                             2: 'Хорошая работа менеджера и отсутствие проблем при подписании договора',
                             3: 'Положительный опыт обслуживания ипотеки',
                             4: 'Выгодные условия, низкая ставка по ипотеке'}
                         }

mapping['creditcards'] = {0: {0: 'Проблемы с списыванием средств и дополнительными комиссиями',
                             1: 'Недовольство условиями акций по карте',
                             2: 'Неудовлетворенность результатом обращения в банк',
                             3: 'Проблемы с исполнением обязательств',
                             4: 'Проблемы с погашением задолженности'},
                         1: {0: 'Эффективное обслуживание и поддержка клиентов',
                             1: 'Удобное приложение',
                             2: 'Удобное оформление карты',
                             3: 'Выгодные условия использования кредитной карты',
                             4: 'Преимущества программ лояльности и рассрочки'}
                         }

mapping['debitcards'] = {0: {0: 'Проблемы с оформлением и предоставлением документов',
                             1: 'Проблемы с доступом к счету',
                             2: 'Проблемы с использованием дебетовой карты',
                             3: 'Неудовлеворенность пенсионеров использованием дебетовой карты',
                             4: 'Неясность условий акций и начисления бонусов'},
                         1: {0: 'Разнообразные финансовые возможности',
                             1: 'Удобство использования мобильного приложения',
                             2: 'Удобство использования дебетовых карт',
                             3: 'Качественное оформление дебетовой карты',
                             4: 'Оперативность работы поддержки'}
                         }

response_decomposition = ResponseDecomposition(
    sentiment_classifier=sentiment_classifier,
    category_classifier=product_classifier,
    topic_modeling=topic_modeling_dict,
    text_transformer=text_transformer
)

# %% [markdown]
# ## Пример с обработкой текста и ряда из текстов

# %%
test_text = "Дебетовые карты? Что? нет, не слышал. Ваша компания - обманщики и лузеры. Я за киберкоммунизм"

result_text = response_decomposition.transform(
    test_text,
    need_topic=True,
    need_sentiment=True,
    need_category=True,
    task_type_sentiment='tfidf',
    classifier_name_sentiment='svm',
    task_type_category='tfidf',
    classifier_name_category='logreg',
    sentiment_for_category_classifier=True,
    threshold_for_sentiment=0.58,
    topic_mapping=mapping
)

result_text
# Out:
#    sentiment    category                                      topic
# 0          0  debitcards  Проблемы с использованием дебетовой карты

# %%
test_series = pd.Series(['Я сказал', 'король молчит', ', а ты кушаешь вопперы'])

result_series = response_decomposition.transform(
    test_series,
    need_topic=True,
    need_sentiment=True,
    need_category=True,
    task_type_sentiment='tfidf',
    classifier_name_sentiment='svm',
    task_type_category='tfidf',
    classifier_name_category='logreg',
    sentiment_for_category_classifier=True,
    threshold_for_sentiment=0.58,
    topic_mapping=mapping
)
result_series
# Out:
#    sentiment    category                                         topic
# 0          0     credits  Проблемы с обслуживанием и обработкой заявок
# 1          1  debitcards          Разнообразные финансовые возможности
# 2          1  debitcards          Разнообразные финансовые возможности

# %% [markdown]
# # Аналитика

# %% [markdown]
# ## Загрузка датафрейма и выделение тем

# %%
data = pd.read_csv('./Вспомогательные файлы/dataset_for_modeling.csv')
data['lemmas'] = data['lemmas'].str.replace(r'[\[\],\']', '').str.split()
data = data[data['grade'] != 'unknown']
data['grade'] = data['grade'].replace({'good' : 1, 'bad' : 0}).astype(int)
data.head(3)
# Out:
#                                                 text             city  \
# 0  21.01.2024 сделала заявку на перенос даты плат...           Москва
# 1  Сталкнулся с такой проблемой что при переводе ...     Екатеринбург
# 2  15-16/01 пытался перевести деньги с дебетовой ...  Санкт-Петербург
#
#          date  rating  grade      bank category      site  \
# 0  2024-01-23       1      0  МТС Банк  credits  banki_ru
# 1  2024-01-23       1      0  МТС Банк  credits  banki_ru
# 2  2024-01-18       2      0  МТС Банк  credits  banki_ru
#
#                     week    month  \
# 0  2024-01-22/2024-01-28  2024-01
# 1  2024-01-22/2024-01-28  2024-01
# 2  2024-01-15/2024-01-21  2024-01
#
#                                     lemmas_with_tags  \
# 0  ['сделать_VERB', 'заявка_NOUN', 'перенос_NOUN'...
# 1  ['проблема_NOUN', 'перевод_NOUN', 'деньги_NOUN...
# 2  ['пытаться_VERB', 'перевести_VERB', 'деньги_NO...
#
#                                               lemmas
# 0  [сделать, заявка, перенос, дата, платеж, прило...
# 1  [проблема, перевод, деньги, заблокировать, опе...
# 2  [пытаться, перевести, деньги, дебетовый, карта...

# %%
response_decomposition = ResponseDecomposition(
    sentiment_classifier=sentiment_classifier,
    category_classifier=product_classifier,
    topic_modeling=topic_modeling_dict,
    text_transformer=text_transformer
)
data['topics'] = response_decomposition._predict_topic(
    data['lemmas'], mapping, data['category'].values, data['grade'].values)

# %%
data.head(2)
# Out:
#                                                 text          city  \
# 0  21.01.2024 сделала заявку на перенос даты плат...        Москва
# 1  Сталкнулся с такой проблемой что при переводе ...  Екатеринбург
#
#          date  rating  grade      bank category      site  \
# 0  2024-01-23       1      0  МТС Банк  credits  banki_ru
# 1  2024-01-23       1      0  МТС Банк  credits  banki_ru
#
#                     week    month  \
# 0  2024-01-22/2024-01-28  2024-01
# 1  2024-01-22/2024-01-28  2024-01
#
#                                     lemmas_with_tags  \
# 0  ['сделать_VERB', 'заявка_NOUN', 'перенос_NOUN'...
# 1  ['проблема_NOUN', 'перевод_NOUN', 'деньги_NOUN...
#
#                                               lemmas  \
# 0  [сделать, заявка, перенос, дата, платеж, прило...
# 1  [проблема, перевод, деньги, заблокировать, опе...
#
#                            topics
# 0  Проблемы с платежами и счетами
# 1  Проблемы с платежами и счетами

# %% [markdown]
# ## OverView

# %%
grouped_data = data.groupby('bank').size()
selected_banks = grouped_data[grouped_data > 100].index.tolist()
filtered_bank_data = data[data['bank'].isin(selected_banks)] # Оставим только банки с 100+ отзывами
filtered_bank_data['site'] = filtered_bank_data['site'].replace({'banki_ru' : 1, 'sravni_ru' : 0})
filtered_bank_data = filtered_bank_data.groupby('bank').agg({'rating' : 'mean', 'date' : 'size', 'site' : 'mean'}).sort_values(by = 'rating', ascending = False)
filtered_bank_data.rename(columns = {'rating' : 'Mean grade', 'date' : 'Number of responses', 'site' : 'Share of banki.ru'}, inplace = True)
filtered_bank_data
# Out:
#                                                  Mean grade  \
# bank
# Банк Точка                                         5.000000
# Банк «Центр-инвест»                                4.945205
# Московский кредитный банк (МКБ)                    4.857143
# Русский Стандарт                                   4.795154
# Совкомбанк                                         4.747432
# Абсолют Банк                                       4.741667
# Кредит Европа Банк                                 4.741007
# Экспобанк                                          4.659218
# Россельхозбанк                                     4.492978
# Альфа-Банк                                         4.457014
# Ренессанс Банк                                     4.009709
# Тинькофф Банк                                      3.705319
# Ozon Банк                                          3.598253
# Уральский банк реконструкции и развития (УБРиР)    3.278261
# МТС Банк                                           3.103343
# Банк «Открытие»                                    2.957576
# ПСБ                                                2.820144
# Газпромбанк                                        2.627376
# Хоум Банк                                          2.618497
# Драйв Клик Банк                                    2.581395
# Банк ДОМ.РФ                                        2.386792
# Росбанк                                            2.289256
# ВТБ                                                2.050938
# Сбербанк                                           1.754161
# Почта Банк                                         1.633094
#
#                                                  Number of responses  \
# bank
# Банк Точка                                                       182
# Банк «Центр-инвест»                                              219
# Московский кредитный банк (МКБ)                                  490
# Русский Стандарт                                                 454
# Совкомбанк                                                      4284
# Абсолют Банк                                                     120
# Кредит Европа Банк                                               278
# Экспобанк                                                        179
# Россельхозбанк                                                   712
# Альфа-Банк                                                      3094
# Ренессанс Банк                                                   103
# Тинькофф Банк                                                    940
# Ozon Банк                                                        229
# Уральский банк реконструкции и развития (УБРиР)                  115
# МТС Банк                                                         329
# Банк «Открытие»                                                  330
# ПСБ                                                              139
# Газпромбанк                                                      526
# Хоум Банк                                                        173
# Драйв Клик Банк                                                  172
# Банк ДОМ.РФ                                                      212
# Росбанк                                                          242
# ВТБ                                                              746
# Сбербанк                                                         781
# Почта Банк                                                       139
#
#                                                  Share of banki.ru
# bank
# Банк Точка                                                0.000000
# Банк «Центр-инвест»                                       0.095890
# Московский кредитный банк (МКБ)                           1.000000
# Русский Стандарт                                          0.991189
# Совкомбанк                                                0.576797
# Абсолют Банк                                              0.791667
# Кредит Европа Банк                                        0.985612
# Экспобанк                                                 0.486034
# Россельхозбанк                                            0.803371
# Альфа-Банк                                                0.626697
# Ренессанс Банк                                            0.300971
# Тинькофф Банк                                             0.786170
# Ozon Банк                                                 0.965066
# Уральский банк реконструкции и развития (УБРиР)           0.556522
# МТС Банк                                                  0.987842
# Банк «Открытие»                                           0.896970
# ПСБ                                                       0.920863
# Газпромбанк                                               0.952471
# Хоум Банк                                                 0.994220
# Драйв Клик Банк                                           0.941860
# Банк ДОМ.РФ                                               0.839623
# Росбанк                                                   0.747934
# ВТБ                                                       0.922252
# Сбербанк                                                  0.877081
# Почта Банк                                                0.884892

# %%
np.corrcoef(filtered_bank_data['Mean grade'], filtered_bank_data['Share of banki.ru'])
# Out:
# array([[ 1.        , -0.46100596],
#        [-0.46100596,  1.        ]])

# %% [markdown]
# Есть гипотеза, что на сравни ру в принципе оставляется меньше плохих отзывов. Но это понимание нам не даст вообще ничего поэтом углубляться в ее проверку не будем

# %% [markdown]
# ## Слабые и сильные стороны каждого банка

# %% [markdown]
# ### В целом в банковском секторе

# %%
data_top_banks = data.copy()
size_of_segment = data_top_banks.groupby(['category', 'grade'])['topics'].size().to_frame()
size_of_segment = size_of_segment.reset_index(level = [0, 1]).rename(columns = {'topics' : 'size of segment'})
grouped_data = data_top_banks.groupby(['category', 'grade'])['topics'].apply(lambda x: x.mode().iloc[0]).reset_index()
topic_counts = data_top_banks.groupby(['category', 'grade'])['topics'].apply(lambda x: x.value_counts(normalize=True)).to_frame()
topic_counts = topic_counts.reset_index(level = [0, 1, 2]).rename(columns = {'level_2' : 'topics', 'topics' : 'share of topic among segment'})
topic_counts['share of topic among segment'] = topic_counts['share of topic among segment'].apply(lambda x: round(x, 2))
grouped_data = grouped_data.merge(topic_counts, on=['category', 'grade', 'topics'], how='left')
grouped_data = grouped_data.merge(size_of_segment, on=['category', 'grade'], how='left')
helpful_frame = grouped_data.groupby(['category'])['size of segment'].sum().rename('size')
grouped_data = grouped_data.merge(helpful_frame, on=['category'], how='left')
grouped_data['share of such sentiment among category'] = (grouped_data['size of segment'] / grouped_data['size']).apply(lambda x: round(x, 2))
grouped_data.drop(columns = ['size'], inplace = True)
grouped_data
# Out:
#        category  grade                                             topics  \
# 0   autocredits      0  Проблемы с процессом обращения и обработки заявки
# 1   autocredits      1  Удовлетворенность процессом оформления автокре...
# 2   creditcards      0   Неудовлетворенность результатом обращения в банк
# 3   creditcards      1                                 Удобное приложение
# 4       credits      0       Проблемы с обслуживанием и обработкой заявок
# 5       credits      1                         Быстрое оформление кредита
# 6    debitcards      0          Проблемы с использованием дебетовой карты
# 7    debitcards      1                     Оперативность работы поддержки
# 8      deposits      0                        Проблемы с доступом к счету
# 9      deposits      1        Положительный опыт обслуживания в отделении
# 10     hypothec      0  Отказы по ипотеке и проблемы с коммуникацией с...
# 11     hypothec      1        Положительный опыт обслуживания в отделении
#
#     share of topic among segment  size of segment  \
# 0                           0.51              650
# 1                           0.61             1332
# 2                           0.79              521
# 3                           0.36             2370
# 4                           0.41              584
# 5                           0.50             2375
# 6                           0.84              684
# 7                           0.33             2043
# 8                           0.73              508
# 9                           0.45             2363
# 10                          0.68             1133
# 11                          0.61             1397
#
#     share of such sentiment among category
# 0                                     0.33
# 1                                     0.67
# 2                                     0.18
# 3                                     0.82
# 4                                     0.20
# 5                                     0.80
# 6                                     0.25
# 7                                     0.75
# 8                                     0.18
# 9                                     0.82
# 10                                    0.45
# 11                                    0.55

# %% [markdown]
# ### В конкретных банках

# %%
data_top_banks = data.copy()
size_of_segment = data_top_banks.groupby(['bank', 'category', 'grade'])['topics'].size().to_frame()
size_of_segment = size_of_segment.reset_index(level = [0, 1, 2]).rename(columns = {'topics' : 'size of segment'})
grouped_data = data_top_banks.groupby(['bank', 'category', 'grade'])['topics'].apply(lambda x: x.mode().iloc[0]).reset_index()
topic_counts = data_top_banks.groupby(['bank', 'category', 'grade'])['topics'].apply(lambda x: x.value_counts(normalize=True)).to_frame()
topic_counts = topic_counts.reset_index(level = [0, 1, 2, 3]).rename(columns = {'level_3' : 'topics', 'topics' : 'share of topic among segment'})
topic_counts['share of topic among segment'] = topic_counts['share of topic among segment'].apply(lambda x: round(x, 2))
grouped_data = grouped_data.merge(topic_counts, on=['bank', 'category', 'grade', 'topics'], how='left')
grouped_data = grouped_data.merge(size_of_segment, on=['bank', 'category', 'grade'], how='left')
helpful_frame = grouped_data.groupby(['bank', 'category'])['size of segment'].sum().rename('size')
grouped_data = grouped_data.merge(helpful_frame, on=['bank', 'category'], how='left')
grouped_data['share of such sentiment among category'] = (grouped_data['size of segment'] / grouped_data['size']).apply(lambda x: round(x, 2))
grouped_data.drop(columns = ['size'], inplace = True)

# %% [markdown]
# Пример:

# %%
grouped_data[grouped_data['bank'] == 'Тинькофф Банк']
# Out:
#               bank     category  grade  \
# 389  Тинькофф Банк  autocredits      0
# 390  Тинькофф Банк  autocredits      1
# 391  Тинькофф Банк  creditcards      0
# 392  Тинькофф Банк  creditcards      1
# 393  Тинькофф Банк      credits      0
# 394  Тинькофф Банк      credits      1
# 395  Тинькофф Банк   debitcards      0
# 396  Тинькофф Банк   debitcards      1
# 397  Тинькофф Банк     deposits      0
# 398  Тинькофф Банк     deposits      1
# 399  Тинькофф Банк     hypothec      0
# 400  Тинькофф Банк     hypothec      1
#
#                                                 topics  \
# 389  Проблемы с процессом обращения и обработки заявки
# 390  Удовлетворенность процессом оформления автокре...
# 391   Неудовлетворенность результатом обращения в банк
# 392      Эффективное обслуживание и поддержка клиентов
# 393       Проблемы с обслуживанием и обработкой заявок
# 394                         Быстрое оформление кредита
# 395          Проблемы с использованием дебетовой карты
# 396                     Оперативность работы поддержки
# 397                        Проблемы с доступом к счету
# 398  Удовлетворение услугами депозитов, предоставля...
# 399  Отказы по ипотеке и проблемы с коммуникацией с...
# 400         Выгодные условия, низкая ставка по ипотеке
#
#      share of topic among segment  size of segment  \
# 389                          0.78               77
# 390                          0.81              132
# 391                          0.90               61
# 392                          0.55              140
# 393                          0.62               52
# 394                          0.35               62
# 395                          0.90               72
# 396                          0.66              198
# 397                          0.50               18
# 398                          0.44               77
# 399                          0.77               22
# 400                          0.38               29
#
#      share of such sentiment among category
# 389                                    0.37
# 390                                    0.63
# 391                                    0.30
# 392                                    0.70
# 393                                    0.46
# 394                                    0.54
# 395                                    0.27
# 396                                    0.73
# 397                                    0.19
# 398                                    0.81
# 399                                    0.43
# 400                                    0.57

# %%
grouped_data[grouped_data['bank'] == 'Альфа-Банк']
# Out:
#           bank     category  grade  \
# 42  Альфа-Банк  autocredits      0
# 43  Альфа-Банк  autocredits      1
# 44  Альфа-Банк  creditcards      0
# 45  Альфа-Банк  creditcards      1
# 46  Альфа-Банк      credits      0
# 47  Альфа-Банк      credits      1
# 48  Альфа-Банк   debitcards      0
# 49  Альфа-Банк   debitcards      1
# 50  Альфа-Банк     deposits      0
# 51  Альфа-Банк     deposits      1
# 52  Альфа-Банк     hypothec      0
# 53  Альфа-Банк     hypothec      1
#
#                                                topics  \
# 42  Проблемы с процессом обращения и обработки заявки
# 43  Удовлетворенность процессом оформления автокре...
# 44   Неудовлетворенность результатом обращения в банк
# 45      Эффективное обслуживание и поддержка клиентов
# 46       Проблемы с обслуживанием и обработкой заявок
# 47                         Быстрое оформление кредита
# 48          Проблемы с использованием дебетовой карты
# 49                     Оперативность работы поддержки
# 50                        Проблемы с доступом к счету
# 51  Удовлетворение услугами депозитов, предоставля...
# 52  Отказы по ипотеке и проблемы с коммуникацией с...
# 53        Положительный опыт обслуживания в отделении
#
#     share of topic among segment  size of segment  \
# 42                          1.00               18
# 43                          0.87              245
# 44                          0.83              105
# 45                          0.42              785
# 46                          0.54               57
# 47                          0.39              298
# 48                          0.75              118
# 49                          0.41              679
# 50                          0.62               34
# 51                          0.44              381
# 52                          0.77               30
# 53                          0.52              344
#
#     share of such sentiment among category
# 42                                    0.07
# 43                                    0.93
# 44                                    0.12
# 45                                    0.88
# 46                                    0.16
# 47                                    0.84
# 48                                    0.15
# 49                                    0.85
# 50                                    0.08
# 51                                    0.92
# 52                                    0.08
# 53                                    0.92

# %% [markdown]
# ## Ключевые проблемы и достоинства работы банков в разрезе городов

# %%
cities_with_more_than_200 = data.groupby('city').size()[data.groupby('city').size() > 200].index
data_top_citys = data[data['city'].isin(cities_with_more_than_200)]
size_of_segment = data_top_citys.groupby(['city', 'category', 'grade'])['topics'].size().to_frame()
size_of_segment = size_of_segment.reset_index(level = [0, 1, 2]).rename(columns = {'topics' : 'size of segment'})
grouped_data = data_top_citys.groupby(['city', 'category', 'grade'])['topics'].apply(lambda x: x.mode().iloc[0]).reset_index()
topic_counts = data_top_citys.groupby(['city', 'category', 'grade'])['topics'].apply(lambda x: x.value_counts(normalize=True)).to_frame()
topic_counts = topic_counts.reset_index(level = [0, 1, 2, 3]).rename(columns = {'level_3' : 'topics', 'topics' : 'share of topic among segment'})
topic_counts['share of topic among segment'] = topic_counts['share of topic among segment'].apply(lambda x: round(x, 2))
grouped_data = grouped_data.merge(topic_counts, on=['city', 'category', 'grade', 'topics'], how='left')
grouped_data = grouped_data.merge(size_of_segment, on=['city', 'category', 'grade'], how='left')
helpful_frame = grouped_data.groupby(['city', 'category'])['size of segment'].sum().rename('size')
grouped_data = grouped_data.merge(helpful_frame, on=['city', 'category'], how='left')
grouped_data['share of such sentiment among category'] = (grouped_data['size of segment'] / grouped_data['size']).apply(lambda x: round(x, 2))
grouped_data.drop(columns = ['size'], inplace = True)
grouped_data
# Out:
#           city     category  grade  \
# 0      Воронеж  autocredits      0
# 1      Воронеж  autocredits      1
# 2      Воронеж  creditcards      0
# 3      Воронеж  creditcards      1
# 4      Воронеж      credits      0
# ..         ...          ...    ...
# 163  Челябинск   debitcards      1
# 164  Челябинск     deposits      0
# 165  Челябинск     deposits      1
# 166  Челябинск     hypothec      0
# 167  Челябинск     hypothec      1
#
#                                                 topics  \
# 0            Неудовлетворительные условия кредитования
# 1    Удовлетворенность процессом оформления автокре...
# 2     Неудовлетворенность результатом обращения в банк
# 3                                   Удобное приложение
# 4         Проблемы с обслуживанием и обработкой заявок
# ..                                                 ...
# 163              Удобство использования дебетовых карт
# 164                        Проблемы с доступом к счету
# 165        Положительный опыт обслуживания в отделении
# 166  Отказы по ипотеке и проблемы с коммуникацией с...
# 167        Положительный опыт обслуживания в отделении
#
#      share of topic among segment  size of segment  \
# 0                            0.43                7
# 1                            0.67               18
# 2                            0.94               16
# 3                            0.37               38
# 4                            0.54               13
# ..                            ...              ...
# 163                          0.34               29
# 164                          0.80                5
# 165                          0.50               24
# 166                          0.82               11
# 167                          0.56               27
#
#      share of such sentiment among category
# 0                                      0.28
# 1                                      0.72
# 2                                      0.30
# 3                                      0.70
# 4                                      0.28
# ..                                      ...
# 163                                    0.76
# 164                                    0.17
# 165                                    0.83
# 166                                    0.29
# 167                                    0.71
#
# [168 rows x 7 columns]

# %%
grouped_data[grouped_data['city'] == 'Воронеж']
# Out:
#        city     category  grade  \
# 0   Воронеж  autocredits      0
# 1   Воронеж  autocredits      1
# 2   Воронеж  creditcards      0
# 3   Воронеж  creditcards      1
# 4   Воронеж      credits      0
# 5   Воронеж      credits      1
# 6   Воронеж   debitcards      0
# 7   Воронеж   debitcards      1
# 8   Воронеж     deposits      0
# 9   Воронеж     deposits      1
# 10  Воронеж     hypothec      0
# 11  Воронеж     hypothec      1
#
#                                                topics  \
# 0           Неудовлетворительные условия кредитования
# 1   Удовлетворенность процессом оформления автокре...
# 2    Неудовлетворенность результатом обращения в банк
# 3                                  Удобное приложение
# 4        Проблемы с обслуживанием и обработкой заявок
# 5                          Быстрое оформление кредита
# 6           Проблемы с использованием дебетовой карты
# 7               Удобство использования дебетовых карт
# 8                         Проблемы с доступом к счету
# 9   Удовлетворение процентными ставками и удобство...
# 10  Отказы по ипотеке и проблемы с коммуникацией с...
# 11        Положительный опыт обслуживания в отделении
#
#     share of topic among segment  size of segment  \
# 0                           0.43                7
# 1                           0.67               18
# 2                           0.94               16
# 3                           0.37               38
# 4                           0.54               13
# 5                           0.56               34
# 6                           0.71               14
# 7                           0.46               28
# 8                           0.67                9
# 9                           0.42               31
# 10                          0.71               17
# 11                          0.62                8
#
#     share of such sentiment among category
# 0                                     0.28
# 1                                     0.72
# 2                                     0.30
# 3                                     0.70
# 4                                     0.28
# 5                                     0.72
# 6                                     0.33
# 7                                     0.67
# 8                                     0.23
# 9                                     0.78
# 10                                    0.68
# 11                                    0.32

# %%
grouped_data[grouped_data['city'] == 'Москва']
# Out:
#       city     category  grade  \
# 48  Москва  autocredits      0
# 49  Москва  autocredits      1
# 50  Москва  creditcards      0
# 51  Москва  creditcards      1
# 52  Москва      credits      0
# 53  Москва      credits      1
# 54  Москва   debitcards      0
# 55  Москва   debitcards      1
# 56  Москва     deposits      0
# 57  Москва     deposits      1
# 58  Москва     hypothec      0
# 59  Москва     hypothec      1
#
#                                                topics  \
# 48  Проблемы с процессом обращения и обработки заявки
# 49  Удовлетворенность процессом оформления автокре...
# 50   Неудовлетворенность результатом обращения в банк
# 51                                 Удобное приложение
# 52       Проблемы с обслуживанием и обработкой заявок
# 53                         Быстрое оформление кредита
# 54          Проблемы с использованием дебетовой карты
# 55       Удобство использования мобильного приложения
# 56                        Проблемы с доступом к счету
# 57        Положительный опыт обслуживания в отделении
# 58  Отказы по ипотеке и проблемы с коммуникацией с...
# 59        Положительный опыт обслуживания в отделении
#
#     share of topic among segment  size of segment  \
# 48                          0.53              165
# 49                          0.72              347
# 50                          0.84              127
# 51                          0.39              495
# 52                          0.44              148
# 53                          0.43              522
# 54                          0.86              163
# 55                          0.28              471
# 56                          0.82              175
# 57                          0.50              715
# 58                          0.75              329
# 59                          0.52              356
#
#     share of such sentiment among category
# 48                                    0.32
# 49                                    0.68
# 50                                    0.20
# 51                                    0.80
# 52                                    0.22
# 53                                    0.78
# 54                                    0.26
# 55                                    0.74
# 56                                    0.20
# 57                                    0.80
# 58                                    0.48
# 59                                    0.52
